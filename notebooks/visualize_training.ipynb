# %% [markdown]
# # Visualize training
#
# This notebook creates visualizations for training losses, validation metrics, etc. during training. The visualizations are used in the thesis report

# %%
import os
import sys
import random
random.seed(42)
from typing import Optional, Any
import warnings
warnings.filterwarnings("ignore")
from pathlib import Path

package_root = os.path.dirname(os.getcwd())
sys.path.insert(0, package_root)

import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
plt.rcParams["savefig.bbox"] = 'tight'
import matplotlib.patches as patches
import seaborn as sns
from matplotlib.ticker import StrMethodFormatter

sns.set(font_scale=1.4)
sns.set_style("whitegrid", {
    "grid.linestyle": 'dashed',
    "axes.edgecolor": '#475569',
    'font.family': ['sans-serif'],
    'font.sans-serif': ['Arial',
        'Droid Sans',
        'sans-serif'
    ],
})
# %matplotlib inline

# %% [markdown]
# **Plot training losses**

# %%
file_path = Path(package_root) / "outputs" / "training_losses" / "train_metrics_losses.csv"
df = pd.read_csv(file_path)
df.columns

columns = [
    'train-main-metrics/epoch',
    'v2_baseline_detr - train-main-metrics/loss',
    'v2_decoder_sparsemax - train-main-metrics/loss',
    'v2_decoder_entmax15 - train-main-metrics/loss',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - train-main-metrics/loss'
]
df = df[columns]
rename_column = {
    'train-main-metrics/epoch': 'epoch',
    'v2_baseline_detr - train-main-metrics/loss': 'softmax',
    'v2_decoder_sparsemax - train-main-metrics/loss': 'sparsemax',
    'v2_decoder_entmax15 - train-main-metrics/loss': 'entmax-1.5',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - train-main-metrics/loss': 'alpha-entmax',
}
df.rename(columns=rename_column, inplace=True)
df = df.set_index('epoch')
df.head(5)

fig, ax = plt.subplots(figsize=(9, 6))
df.plot(ax=ax)
ax.set_xlabel("Training epoch")
ax.set_ylabel("Training loss")

fig.savefig("images/training/training_losses.png", bbox_inches="tight")
fig.savefig("images/training/training_losses.pdf", bbox_inches="tight")

# %% [markdown]
# **Plot training CE losses**

# %%
file_path = Path(package_root) / "outputs" / "training_losses" / "train_metrics_ce_loss.csv"
df = pd.read_csv(file_path)
df.columns

columns = [
    'train-main-metrics/epoch',
    'v2_baseline_detr - train-main-metrics/loss_ce',
    'v2_decoder_sparsemax - train-main-metrics/loss_ce',
    'v2_decoder_entmax15 - train-main-metrics/loss_ce',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - train-main-metrics/loss_ce'
]
df = df[columns]
rename_column = {
    'train-main-metrics/epoch': 'epoch',
    'v2_baseline_detr - train-main-metrics/loss_ce': 'softmax',
    'v2_decoder_sparsemax - train-main-metrics/loss_ce': 'sparsemax',
    'v2_decoder_entmax15 - train-main-metrics/loss_ce': 'entmax-1.5',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - train-main-metrics/loss_ce': 'alpha-entmax',
}
df.rename(columns=rename_column, inplace=True)
df = df.set_index('epoch')
df.head(5)

fig, ax = plt.subplots(figsize=(9, 6))
df.plot(ax=ax)
ax.set_xlabel("Training epoch")
ax.set_ylabel("CE loss")

fig.savefig("images/training/training_ce_loss.png", bbox_inches="tight")
fig.savefig("images/training/training_ce_loss.pdf", bbox_inches="tight")

# %% [markdown]
# **Plot traiing bbox losses**

# %%
file_path = Path(package_root) / "outputs" / "training_losses" / "train_metrics_bbox_loss.csv"
df = pd.read_csv(file_path)
df.columns

columns = [
    'train-main-metrics/epoch',
    'v2_baseline_detr - train-main-metrics/loss_bbox',
    'v2_decoder_sparsemax - train-main-metrics/loss_bbox',
    'v2_decoder_entmax15 - train-main-metrics/loss_bbox',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - train-main-metrics/loss_bbox'
]
df = df[columns]
rename_column = {
    'train-main-metrics/epoch': 'epoch',
    'v2_baseline_detr - train-main-metrics/loss_bbox': 'softmax',
    'v2_decoder_sparsemax - train-main-metrics/loss_bbox': 'sparsemax',
    'v2_decoder_entmax15 - train-main-metrics/loss_bbox': 'entmax-1.5',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - train-main-metrics/loss_bbox': 'alpha-entmax',
}
df.rename(columns=rename_column, inplace=True)
df = df.set_index('epoch')
df.head(5)

fig, ax = plt.subplots(figsize=(9, 6))
df.plot(ax=ax)
ax.set_xlabel("Training epoch")
ax.set_ylabel("Bounding-box loss")

fig.savefig("images/training/training_bbox_loss.png", bbox_inches="tight")
fig.savefig("images/training/training_bbox_loss.pdf", bbox_inches="tight")

# %% [markdown]
# **Plot trainig gIoU losses**

# %%
file_path = Path(package_root) / "outputs" / "training_losses" / "train_metrics_giou_loss.csv"
df = pd.read_csv(file_path)
df.columns

columns = [
    'train-main-metrics/epoch',
    'v2_baseline_detr - train-main-metrics/loss_giou',
    'v2_decoder_sparsemax - train-main-metrics/loss_giou',
    'v2_decoder_entmax15 - train-main-metrics/loss_giou',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - train-main-metrics/loss_giou'
]
df = df[columns]
rename_column = {
    'train-main-metrics/epoch': 'epoch',
    'v2_baseline_detr - train-main-metrics/loss_giou': 'softmax',
    'v2_decoder_sparsemax - train-main-metrics/loss_giou': 'sparsemax',
    'v2_decoder_entmax15 - train-main-metrics/loss_giou': 'entmax-1.5',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - train-main-metrics/loss_giou': 'alpha-entmax',
}
df.rename(columns=rename_column, inplace=True)
df = df.set_index('epoch')
df.head(5)

fig, ax = plt.subplots(figsize=(9, 6))
df.plot(ax=ax)
ax.set_xlabel("Training epoch")
ax.set_ylabel("Generalized IoU loss")

fig.savefig("images/training/training_giou_loss.png", bbox_inches="tight")
fig.savefig("images/training/training_giou_loss.pdf", bbox_inches="tight")

# %% [markdown]
# **Plot class error losses**

# %%
file_path = Path(package_root) / "outputs" / "training_losses" / "train_metrics_class_error.csv"
df = pd.read_csv(file_path)
df.columns

columns = [
    'train-main-metrics/epoch',
    'v2_baseline_detr - train-main-metrics/class_error',
    'v2_decoder_sparsemax - train-main-metrics/class_error',
    'v2_decoder_entmax15 - train-main-metrics/class_error',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - train-main-metrics/class_error'
]
df = df[columns]
rename_column = {
    'train-main-metrics/epoch': 'epoch',
    'v2_baseline_detr - train-main-metrics/class_error': 'softmax',
    'v2_decoder_sparsemax - train-main-metrics/class_error': 'sparsemax',
    'v2_decoder_entmax15 - train-main-metrics/class_error': 'entmax-1.5',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - train-main-metrics/class_error': 'alpha-entmax',
}
df.rename(columns=rename_column, inplace=True)
df = df.set_index('epoch')
df.head(5)

fig, ax = plt.subplots(figsize=(9, 6))
df.plot(ax=ax)
ax.set_xlabel("Training epoch")
ax.set_ylabel("Class error loss")

fig.savefig("images/training/training_class_error.png", bbox_inches="tight")
fig.savefig("images/training/training_class_error.pdf", bbox_inches="tight")

# %% [markdown]
# **Plot cardinality errors**

# %%
file_path = Path(package_root) / "outputs" / "training_losses" / "train_metrics_cardinality_error.csv"
df = pd.read_csv(file_path)
df.columns

columns = [
    'train-main-metrics/epoch',
    'v2_baseline_detr - train-main-metrics/cardinality_error_unscaled',
    'v2_decoder_sparsemax - train-main-metrics/cardinality_error_unscaled',
    'v2_decoder_entmax15 - train-main-metrics/cardinality_error_unscaled',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - train-main-metrics/cardinality_error_unscaled'
]
df = df[columns]
rename_column = {
    'train-main-metrics/epoch': 'epoch',
    'v2_baseline_detr - train-main-metrics/cardinality_error_unscaled': 'softmax',
    'v2_decoder_sparsemax - train-main-metrics/cardinality_error_unscaled': 'sparsemax',
    'v2_decoder_entmax15 - train-main-metrics/cardinality_error_unscaled': 'entmax-1.5',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - train-main-metrics/cardinality_error_unscaled': 'alpha-entmax',
}
df.rename(columns=rename_column, inplace=True)
df = df.set_index('epoch')
df.head(5)

fig, ax = plt.subplots(figsize=(9, 6))
df.plot(ax=ax)
ax.set_xlabel("Training epoch")
ax.set_ylabel("Cardinality error loss")

fig.savefig("images/training/training_cardinality_error.png", bbox_inches="tight")
fig.savefig("images/training/training_cardinality_error.pdf", bbox_inches="tight")

# %% [markdown]
# ## Validation metrics

# %%
file_path = Path(package_root) / "outputs" / "val_metrics" / "val_metrics_map.csv"
df = pd.read_csv(file_path)
df.columns

columns = [
    'val-AP/epoch',
    'v2_baseline_detr - val-AP/mAP',
    'v2_decoder_sparsemax - val-AP/mAP',
    'v2_decoder_entmax15 - val-AP/mAP',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - val-AP/mAP'
]
df = df[columns]
rename_column = {
    'val-AP/epoch': 'epoch',
    'v2_baseline_detr - val-AP/mAP': 'softmax',
    'v2_decoder_sparsemax - val-AP/mAP': 'sparsemax',
    'v2_decoder_entmax15 - val-AP/mAP': 'entmax-1.5',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - val-AP/mAP': 'alpha-entmax',
}
df.rename(columns=rename_column, inplace=True)
df = df.set_index('epoch')
df.head(5)

fig, ax = plt.subplots(figsize=(9, 6))
df.plot(ax=ax)
ax.set_xlabel("Training epoch")
ax.set_ylabel("mAP")

fig.savefig("images/val_metrics/mAP.png", bbox_inches="tight")
fig.savefig("images/val_metrics/mAP.pdf", bbox_inches="tight")

# %% [markdown]
# **AP-50**

# %%
file_path = Path(package_root) / "outputs" / "val_metrics" / "val_metrics_ap50.csv"
df = pd.read_csv(file_path)
df.columns

columns = [
    'val-AP/epoch',
    'v2_baseline_detr - val-AP/AP_50',
    'v2_decoder_sparsemax - val-AP/AP_50',
    'v2_decoder_entmax15 - val-AP/AP_50',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - val-AP/AP_50'
]
df = df[columns]
rename_column = {
    'val-AP/epoch': 'epoch',
    'v2_baseline_detr - val-AP/AP_50': 'softmax',
    'v2_decoder_sparsemax - val-AP/AP_50': 'sparsemax',
    'v2_decoder_entmax15 - val-AP/AP_50': 'entmax-1.5',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - val-AP/AP_50': 'alpha-entmax',
}
df.rename(columns=rename_column, inplace=True)
df = df.set_index('epoch')
df.head(5)

fig, ax = plt.subplots(figsize=(9, 6))
df.plot(ax=ax)
ax.set_xlabel("Training epoch")
ax.set_ylabel(r"$\mathrm{AP}_{50}$")

fig.savefig("images/val_metrics/AP_50.png", bbox_inches="tight")
fig.savefig("images/val_metrics/AP_50.pdf", bbox_inches="tight")

# %% [markdown]
# **AP-75**

# %%
file_path = Path(package_root) / "outputs" / "val_metrics" / "val_metrics_ap75.csv"
df = pd.read_csv(file_path)
df.columns

columns = [
    'val-AP/epoch',
    'v2_baseline_detr - val-AP/AP_75',
    'v2_decoder_sparsemax - val-AP/AP_75',
    'v2_decoder_entmax15 - val-AP/AP_75',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - val-AP/AP_75'
]
df = df[columns]
rename_column = {
    'val-AP/epoch': 'epoch',
    'v2_baseline_detr - val-AP/AP_75': 'softmax',
    'v2_decoder_sparsemax - val-AP/AP_75': 'sparsemax',
    'v2_decoder_entmax15 - val-AP/AP_75': 'entmax-1.5',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - val-AP/AP_75': 'alpha-entmax',
}
df.rename(columns=rename_column, inplace=True)
df = df.set_index('epoch')
df.head(5)

fig, ax = plt.subplots(figsize=(9, 6))
df.plot(ax=ax)
ax.set_xlabel("Training epoch")
ax.set_ylabel(r"$\mathrm{AP}_{75}$")

fig.savefig("images/val_metrics/AP_75.png", bbox_inches="tight")
fig.savefig("images/val_metrics/AP_75.pdf", bbox_inches="tight")

# %% [markdown]
# **AP-L**

# %%
file_path = Path(package_root) / "outputs" / "val_metrics" / "val_metrics_apL.csv"
df = pd.read_csv(file_path)
df.columns

columns = [
    'val-AP/epoch',
    'v2_baseline_detr - val-AP/AP_L',
    'v2_decoder_sparsemax - val-AP/AP_L',
    'v2_decoder_entmax15 - val-AP/AP_L',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - val-AP/AP_L'
]
df = df[columns]
rename_column = {
    'val-AP/epoch': 'epoch',
    'v2_baseline_detr - val-AP/AP_L': 'softmax',
    'v2_decoder_sparsemax - val-AP/AP_L': 'sparsemax',
    'v2_decoder_entmax15 - val-AP/AP_L': 'entmax-1.5',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - val-AP/AP_L': 'alpha-entmax',
}
df.rename(columns=rename_column, inplace=True)
df = df.set_index('epoch')
df.head(5)

fig, ax = plt.subplots(figsize=(9, 6))
df.plot(ax=ax)
ax.set_xlabel("Training epoch")
ax.set_ylabel(r"$\mathrm{AP}_{L}$")

fig.savefig("images/val_metrics/AP_L.png", bbox_inches="tight")
fig.savefig("images/val_metrics/AP_L.pdf", bbox_inches="tight")

# %% [markdown]
# **AP-M**

# %%
file_path = Path(package_root) / "outputs" / "val_metrics" / "val_metrics_apM.csv"
df = pd.read_csv(file_path)
df.columns

columns = [
    'val-AP/epoch',
    'v2_baseline_detr - val-AP/AP_M',
    'v2_decoder_sparsemax - val-AP/AP_M',
    'v2_decoder_entmax15 - val-AP/AP_M',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - val-AP/AP_M'
]
df = df[columns]
rename_column = {
    'val-AP/epoch': 'epoch',
    'v2_baseline_detr - val-AP/AP_M': 'softmax',
    'v2_decoder_sparsemax - val-AP/AP_M': 'sparsemax',
    'v2_decoder_entmax15 - val-AP/AP_M': 'entmax-1.5',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - val-AP/AP_M': 'alpha-entmax',
}
df.rename(columns=rename_column, inplace=True)
df = df.set_index('epoch')
df.head(5)

fig, ax = plt.subplots(figsize=(9, 6))
df.plot(ax=ax)
ax.set_xlabel("Training epoch")
ax.set_ylabel(r"$\mathrm{AP}_{M}$")

fig.savefig("images/val_metrics/AP_M.png", bbox_inches="tight")
fig.savefig("images/val_metrics/AP_M.pdf", bbox_inches="tight")

# %% [markdown]
# **AP-S**

# %%
file_path = Path(package_root) / "outputs" / "val_metrics" / "val_metrics_apS.csv"
df = pd.read_csv(file_path)
df.columns

columns = [
    'val-AP/epoch',
    'v2_baseline_detr - val-AP/AP_S',
    'v2_decoder_sparsemax - val-AP/AP_S',
    'v2_decoder_entmax15 - val-AP/AP_S',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - val-AP/AP_S'
]
df = df[columns]
rename_column = {
    'val-AP/epoch': 'epoch',
    'v2_baseline_detr - val-AP/AP_S': 'softmax',
    'v2_decoder_sparsemax - val-AP/AP_S': 'sparsemax',
    'v2_decoder_entmax15 - val-AP/AP_S': 'entmax-1.5',
    'v2_decoder_a-entmax_alpha-lr=1e-3 - val-AP/AP_S': 'alpha-entmax',
}
df.rename(columns=rename_column, inplace=True)
df = df.set_index('epoch')
df.head(5)

fig, ax = plt.subplots(figsize=(9, 6))
df.plot(ax=ax)
ax.set_xlabel("Training epoch")
ax.set_ylabel(r"$\mathrm{AP}_{S}$")

fig.savefig("images/val_metrics/AP_S.png", bbox_inches="tight")
fig.savefig("images/val_metrics/AP_S.pdf", bbox_inches="tight")
